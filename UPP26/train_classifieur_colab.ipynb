# %% [markdown]
# <a href="https://colab.research.google.com/github/maramgueye/projet_fairness/blob/main/UPP26/train_classifieur_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Only for Google Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Only for Google Colab
import sys

# In your google drive, create a folder for the Fairness project
# (called here 'coursFairness')
# Copy in this folder the python file train_classifieur.py
# Copy in this folder your zipped data folder (called here 'YOUR_NAME.zip')

# Path to the folder containing the python file
drive_module_path = "/content/drive/MyDrive/coursFairness"
sys.path.append(drive_module_path)

# Verify the path was added
print(sys.path[-1])
# Out:
# /content/drive/MyDrive/coursFairness

# %%
from google.colab import drive
drive.mount('/content/drive')

# !ls -lh /content/drive/MyDrive/coursFairness
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# total 203M
# -rw------- 1 root root 203M Mar 13 09:49 Gueye_Maram_Sall.zip
# -rw------- 1 root root  18K Mar 13 09:08 train_classifieur.py

# %%
# !file "/content/drive/MyDrive/coursFairness/Gueye_Maram_Sall.zip"
# Out:
# /content/drive/MyDrive/coursFairness/Gueye_Maram_Sall.zip: Zip archive data, at least v2.0 to extract, compression method=store

# %%
# Only for Google Colab
# !pip install pandas\
  numpy\
  torchvision\
  torch\
  torchmetrics\
  tensorboard\
  pillow\
  lightning\
  matplotlib\
  scikit_learn\
  ipykernel \
  fairlearn \
  plotly \
  nbformat \
  aif360["inFairness"] \
  aif360['AdversarialDebiasing'] \
  causal-learn \
  BlackBoxAuditing \
  cvxpy \
  dice-ml \
  lime \
  shapkit

# %%
# !unzip -v "/content/drive/MyDrive/coursFairness/Gueye_Maram_Sall.zip"
# Out:
# Archive:  /content/drive/MyDrive/coursFairness/Gueye_Maram_Sall.zip
#  Length   Method    Size  Cmpr    Date    Time   CRC-32   Name
# --------  ------  ------- ---- ---------- ----- --------  ----
#        0  Stored        0   0% 2026-02-20 12:31 00000000  train/
#        0  Stored        0   0% 2026-02-20 12:31 00000000  valid/
#   416191  Defl:N    48024  89% 2026-02-20 12:31 3b358521  metadata.csv
#        0  Stored        0   0% 2026-02-20 12:31 00000000  valid/malade/
#        0  Stored        0   0% 2026-02-20 12:31 00000000  valid/sain/
#    35297  Defl:N    35298   0% 2026-02-20 12:31 45f8ebaa  valid/malade/00028811_002.png
#    40867  Defl:N    40855   0% 2026-02-20 12:31 b89dd3f5  valid/malade/00030267_001.png
#    45158  Defl:N    45092   0% 2026-02-20 12:31 263b686b  valid/malade/00002042_003.png
#    47189  Defl:N    47120   0% 2026-02-20 12:31 da11dee4  valid/malade/00005079_016.png
# ...

# %%
# Only for Google Colab
# !cp /content/drive/MyDrive/coursFairness/Gueye_Maram_Sall.zip /content/
# !mkdir /content/DATA/
# !unzip Gueye_Maram_Sall.zip -d /content/DATA/
# Out:
# mkdir: cannot create directory ‘/content/DATA/’: File exists
# Archive:  Gueye_Maram_Sall.zip
#    creating: /content/DATA/train/
#    creating: /content/DATA/valid/
#   inflating: /content/DATA/metadata.csv
#    creating: /content/DATA/valid/malade/
#    creating: /content/DATA/valid/sain/
#   inflating: /content/DATA/valid/malade/00028811_002.png
#   inflating: /content/DATA/valid/malade/00030267_001.png
#   inflating: /content/DATA/valid/malade/00002042_003.png
#   inflating: /content/DATA/valid/malade/00005079_016.png
#   inflating: /content/DATA/valid/malade/00002059_010.png
#   inflating: /content/DATA/valid/malade/00002337_012.png
#   inflating: /content/DATA/valid/malade/00022604_026.png
#   inflating: /content/DATA/valid/malade/00017325_013.png
#   inflating: /content/DATA/valid/malade/00022604_018.png
#   inflating: /content/DATA/valid/malade/00012233_002.png
#   inflating: /content/DATA/valid/malade/00015147_001.png
# ...

# %%
# !ls -R /content/DATA/
# Out:
# /content/DATA/:
# metadata.csv  train  valid
#
# /content/DATA/train:
# malade	sain
#
# /content/DATA/train/malade:
# 00000011_000.png  00009118_000.png  00017362_004.png  00020499_003.png
# 00000011_005.png  00009239_001.png  00017362_005.png  00020499_005.png
# 00000011_006.png  00009239_002.png  00017362_007.png  00020499_006.png
# 00000011_007.png  00009239_003.png  00017362_008.png  00020499_007.png
# 00000028_000.png  00009239_009.png  00017362_009.png  00020499_008.png
# 00000063_000.png  00009244_000.png  00017362_010.png  00020499_009.png
# 00000132_001.png  00009256_001.png  00017362_011.png  00020499_010.png
# 00000132_002.png  00009256_002.png  00017362_014.png  00020499_011.png
# 00000132_003.png  00009256_003.png  00017362_018.png  00020505_000.png
# 00000132_004.png  00009256_005.png  00017362_020.png  00020505_002.png
# 00000132_005.png  00009256_006.png  00017405_000.png  00020505_003.png
# 00000132_006.png  00009256_007.png  00017405_003.png  00020505_005.png
# ...

# %%
# !ls /content/drive/MyDrive/coursFairness
# Out:
# Gueye_Maram_Sall.zip  train_classifieur.py

# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.append('/content/drive/MyDrive/coursFairness')

from train_classifieur import train_classifier, pred_classifier
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2264/978728236.py in <cell line: 0>()
#       5 sys.path.append('/content/drive/MyDrive/coursFairness')
#       6
# ----> 7 from train_classifieur import train_classifier, pred_classifier
#
# ModuleNotFoundError: No module named 'train_classifieur'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
```python
# !cat /content/drive/MyDrive/coursFairness/train_classifieur.py
```

# %%
# !ls -lh /content/drive/MyDrive/coursFairness
# Out:
# total 203M
# -rw------- 1 root root 203M Mar 13 09:49 Gueye_Maram_Sall.zip
# -rw------- 1 root root  18K Mar 13 09:08 train_classifieur.py

# %%
# !file "/content/drive/MyDrive/coursFairness/Gueye_Maram_Sall.zip"
# Out:
# /content/drive/MyDrive/coursFairness/Gueye_Maram_Sall.zip: Zip archive data, at least v2.0 to extract, compression method=store

# %%
# !unzip -v "/content/drive/MyDrive/coursFairness/Gueye_Maram_Sall.zip"
# Out:
# Archive:  /content/drive/MyDrive/coursFairness/Gueye_Maram_Sall.zip
#  Length   Method    Size  Cmpr    Date    Time   CRC-32   Name
# --------  ------  ------- ---- ---------- ----- --------  ----
#        0  Stored        0   0% 2026-02-20 12:31 00000000  train/
#        0  Stored        0   0% 2026-02-20 12:31 00000000  valid/
#   416191  Defl:N    48024  89% 2026-02-20 12:31 3b358521  metadata.csv
#        0  Stored        0   0% 2026-02-20 12:31 00000000  valid/malade/
#        0  Stored        0   0% 2026-02-20 12:31 00000000  valid/sain/
#    35297  Defl:N    35298   0% 2026-02-20 12:31 45f8ebaa  valid/malade/00028811_002.png
#    40867  Defl:N    40855   0% 2026-02-20 12:31 b89dd3f5  valid/malade/00030267_001.png
#    45158  Defl:N    45092   0% 2026-02-20 12:31 263b686b  valid/malade/00002042_003.png
#    47189  Defl:N    47120   0% 2026-02-20 12:31 da11dee4  valid/malade/00005079_016.png
# ...

# %%
# !unzip -o "/content/drive/MyDrive/coursFairness/Gueye_Maram_Sall.zip" -d /content/DATA/
# Out:
# Archive:  /content/drive/MyDrive/coursFairness/Gueye_Maram_Sall.zip
#   inflating: /content/DATA/metadata.csv
#   inflating: /content/DATA/valid/malade/00028811_002.png
#   inflating: /content/DATA/valid/malade/00030267_001.png
#   inflating: /content/DATA/valid/malade/00002042_003.png
#   inflating: /content/DATA/valid/malade/00005079_016.png
#   inflating: /content/DATA/valid/malade/00002059_010.png
#   inflating: /content/DATA/valid/malade/00002337_012.png
#   inflating: /content/DATA/valid/malade/00022604_026.png
#   inflating: /content/DATA/valid/malade/00017325_013.png
#   inflating: /content/DATA/valid/malade/00022604_018.png
#   inflating: /content/DATA/valid/malade/00012233_002.png
#   inflating: /content/DATA/valid/malade/00015147_001.png
#   inflating: /content/DATA/valid/malade/00013625_055.png
#   inflating: /content/DATA/valid/malade/00017325_017.png
#   inflating: /content/DATA/valid/malade/00003515_001.png
#   inflating: /content/DATA/valid/malade/00022604_008.png
# ...

# %%
from train_classifieur import train_classifier, pred_classifier
from datetime import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2264/101315202.py in <cell line: 0>()
# ----> 1 from train_classifieur import train_classifier, pred_classifier
#       2 from datetime import datetime
#
# ModuleNotFoundError: No module named 'train_classifieur'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device

# %%
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')

# %%
# %%time
# This cell show how to train a model
#
# You are going to train several time the models, with different weights
#
# The experiment folder name (logdir) suggested contains the timestamp
# you can change this to add some description in the name
# or add a file in the logdir folder to describe your intention and parameters
# Warning: For Colab users, the logdir needs to be on your drive (as in this example)
# It will allow you to keep your trained models, even if you get disconnected
#
# By default, to help you reproduce you experiments the csv file
# used for the training is copied in the logdir folder.

# This can take around 20-30min to run on PUIO computer
# And around 10 min on Colab with a GPU

dt = datetime.now()
timeStamp = dt.strftime('%Y_%m_%d_%H_%M_%S')
logdir = f"{drive_module_path}/expe_log/{timeStamp}"
ckpt_path, ckpt_score = train_classifier(
    logdir=logdir,
    datadir=f"./DATA/",
    csv=f"./DATA/metadata.csv",
    weights_col="WEIGHTS")

# %%
# %load_ext tensorboard
# %tensorboard --logdir=$logdir

# %%
# %%time
# This cell show how to perform predictions with a train model
# the ckpt_path outputed in the previous cell refer to the best model obtained
# during the training, you can replace this by any .ckpt file obtained
pred_classifier(
    datadir=f"./DATA/",
    csv_in=f"./DATA/metadata.csv",
    csv_out=f"{logdir}/preds.csv",
    ckpt_path = ckpt_path
)
